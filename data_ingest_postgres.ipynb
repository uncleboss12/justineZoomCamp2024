# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv.gz', nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30                1
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34                1
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13                1
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_tripdata_2021-01.csv.gz'))
# Out:
# CREATE TABLE "yellow_tripdata_2021-01.csv.gz" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
# Define the connection string
conn_str = 'postgresql://root:root@localhost:5432/ny_taxi'

# Create the connection
engine = create_engine(conn_str)

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv.gz', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(name='yellow_tripdata_2021-01.csv.gz', con=engine, if_exists='replace' )
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_tripdata_2021-01.csv.gz', con=engine, if_exists='append' )
# Out:
# CPU times: user 6.11 s, sys: 143 ms, total: 6.26 s
# Wall time: 8.79 s
# 1000

# %%
from time import time

# %%
while True:

    t_start = time()
    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)


    df.to_sql(name='yellow_tripdata_2021-01.csv.gz', con=engine, if_exists='append' )

    t_end = time()


    print('inserted another chunk..., took %.3f seconds ' % (t_end - t_start))
# Out:
# inserted another chunk..., took 8.899 seconds
# inserted another chunk..., took 8.814 seconds
# inserted another chunk..., took 8.989 seconds
# inserted another chunk..., took 8.994 seconds
# inserted another chunk..., took 8.990 seconds
# inserted another chunk..., took 9.106 seconds
# inserted another chunk..., took 8.971 seconds
# inserted another chunk..., took 9.053 seconds
# inserted another chunk..., took 8.915 seconds
# inserted another chunk..., took 8.799 seconds
# inserted another chunk..., took 9.391 seconds
# /tmp/ipykernel_66389/3675489967.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk..., took 9.269 seconds
# inserted another chunk..., took 5.752 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 4
#       1 while True:
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2024-01-20 22:51:10--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.13.214, 16.182.73.32, 52.216.41.248, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.13.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi+_zone_lookup.csv’
#
# taxi+_zone_lookup.c 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2024-01-20 22:51:10 (30.1 MB/s) - ‘taxi+_zone_lookup.csv’ saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""
pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT * 
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
     schemaname != 'information_schema'; 
"""
pd.read_sql(query, con=engine)
# Out:
#   schemaname                       tablename tableowner tablespace  \
# 0     public                           zones       root       None
# 1     public   green_tripdata_2019-09.csv.gz       root       None
# 2     public  yellow_tripdata_2021-01.csv.gz       root       None
#
#    hasindexes  hasrules  hastriggers  rowsecurity
# 0        True     False        False        False
# 1        True     False        False        False
# 2        True     False        False        False
